# %% [markdown]
# <a href="https://colab.research.google.com/github/brunoribeiro122/DataScience/blob/main/PandasPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# AULA1 PANDAS

# %% [markdown]
# #AULA 1- PANDAS

# %%
import pandas as pd

# %%
base = pd.read_excel('/content/drive/MyDrive/base_cida/selecao.xlsx')
base2 = pd.read_excel('/content/drive/MyDrive/base_cida/selecaofic.xlsx')

# %%
display(base)
display(base2)
# Out:
#       SELEÇÃO  TITULOS MUNDIAIS  VICE CAMPEONATO  3° LUGAR
# 0      BRASIL                 5                2         2
# 1  ARGENTINA                  3                3         0
# 2    ALEMANHA                 4                4         4
#        SELEÇÃO  TITULOS MUNDIAIS  VICE CAMPEONATO  3° LUGAR
# 0      Belgica                 3                2         2
# 1    Dinamarca                 5               25         7
# 2        Chile                 7                3         3
# 3      Bolivia                 2                7         7
# 4        Qatar                 1                9         2
# 5       Arabia                 3                0         1
# 6       Angola                 5                4         3
# 7   Inglaterra                 7                2         2
# 8      Uruguai                 5                6        34
# 9       Italia                 1                4        64
# 10      França                 3                3         1
# ...

# %%
tabela = {'selecao': ['Brasil', 'Argentina', 'Alemanha'],
          'mundiais': ['5','3','4'],
          'vice campeao': ['2','3','4']}

# %%
dataframe = pd.DataFrame(tabela)

# %%
display(dataframe)

# %%
base.head()
# Out:
#       SELEÇÃO  TITULOS MUNDIAIS  VICE CAMPEONATO  3° LUGAR
# 0      BRASIL                 5                2         2
# 1  ARGENTINA                  3                3         0
# 2    ALEMANHA                 4                4         4

# %%
display(base.head(1))
# Out:
#   SELEÇÃO  TITULOS MUNDIAIS  VICE CAMPEONATO  3° LUGAR
# 0  BRASIL                 5                2         2

# %%
print(base.shape)
# Out:
# (3, 4)

# %%
display(base.describe())
# Out:
#        TITULOS MUNDIAIS  VICE CAMPEONATO  3° LUGAR
# count               3.0              3.0       3.0
# mean                4.0              3.0       2.0
# std                 1.0              1.0       2.0
# min                 3.0              2.0       0.0
# 25%                 3.5              2.5       1.0
# 50%                 4.0              3.0       2.0
# 75%                 4.5              3.5       3.0
# max                 5.0              4.0       4.0

# %%
titulos = base[['VICE CAMPEONATO']]

# %%
display(titulos)
# Out:
#    VICE CAMPEONATO
# 0                2
# 1                3
# 2                4

# %%
print(base)
# Out:
#       SELEÇÃO  TITULOS MUNDIAIS  VICE CAMPEONATO  3° LUGAR
# 0      BRASIL                 5                2         2
# 1  ARGENTINA                  3                3         0
# 2    ALEMANHA                 4                4         4

# %%
selecao = base[['SELEÇÃO', 'TITULOS MUNDIAIS']]

# %%
display(selecao)
# Out:
#       SELEÇÃO  TITULOS MUNDIAIS
# 0      BRASIL                 5
# 1  ARGENTINA                  3
# 2    ALEMANHA                 4

# %%
display(base.iloc[:2])
display(base)
# Out:
#       SELEÇÃO  TITULOS MUNDIAIS  VICE CAMPEONATO  3° LUGAR
# 0      BRASIL                 5                2         2
# 1  ARGENTINA                  3                3         0
#       SELEÇÃO  TITULOS MUNDIAIS  VICE CAMPEONATO  3° LUGAR
# 0      BRASIL                 5                2         2
# 1  ARGENTINA                  3                3         0
# 2    ALEMANHA                 4                4         4

# %%
selecoesmund = base.loc[base['SELEÇÃO'] == 'BRASIL']
display(selecoesmund)
# Out:
#   SELEÇÃO  TITULOS MUNDIAIS  VICE CAMPEONATO  3° LUGAR
# 0  BRASIL                 5                2         2

# %%
vices = base.loc[base['SELEÇÃO'] == 'BRASIL',['SELEÇÃO','TITULOS MUNDIAIS','VICE CAMPEONATO','3° LUGAR']]
display(vices)
# Out:
#   SELEÇÃO  TITULOS MUNDIAIS  VICE CAMPEONATO  3° LUGAR
# 0  BRASIL                 5                2         2

# %%
print(base.loc[1,'SELEÇÃO'])
# Out:
# ARGENTINA

# %%
base.loc[:1, "titulos Perdidos"] = 6

# %%
print(base)
# Out:
#       SELEÇÃO  TITULOS MUNDIAIS  VICE CAMPEONATO  3° LUGAR  titulos Perdidos
# 0      BRASIL                 5                2         2               6.0
# 1  ARGENTINA                  3                3         0               6.0
# 2    ALEMANHA                 4                4         4               NaN

# %%
base['VICE CAMPEONATO'] = base2['TITULOS MUNDIAIS'] - 0.05
display(base)
# Out:
#       SELEÇÃO  TITULOS MUNDIAIS  VICE CAMPEONATO  3° LUGAR  titulos Perdidos
# 0      BRASIL                 5             2.95         2               6.0
# 1  ARGENTINA                  3             4.95         0               6.0
# 2    ALEMANHA                 4             6.95         4               NaN

# %%
base = base.reset_index()
display(base)
# Out:
#    index     SELEÇÃO  TITULOS MUNDIAIS  VICE CAMPEONATO  3° LUGAR  \
# 0      0      BRASIL                 5             2.95         2
# 1      1  ARGENTINA                  3             4.95         0
# 2      2    ALEMANHA                 4             6.95         4
#
#    titulos Perdidos
# 0               6.0
# 1               6.0
# 2               NaN

# %%
basesemmudial = base.drop("TITULOS MUNDIAIS", axis=1)
display(basesemmudial)
# Out:
#    index     SELEÇÃO  VICE CAMPEONATO  3° LUGAR  titulos Perdidos
# 0      0      BRASIL             2.95         2               6.0
# 1      1  ARGENTINA              4.95         0               6.0
# 2      2    ALEMANHA             6.95         4               NaN

# %%
base2.to_excel(r'basesemmundial.xlsx', index=False)

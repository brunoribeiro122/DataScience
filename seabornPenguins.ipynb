# %% [markdown]
# <a href="https://colab.research.google.com/github/brunoribeiro122/DataScience/blob/main/seabornPenguins.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd

# %%
pinguins = sns.load_dataset("Penguins")
display(pinguins)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
pinguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
pinguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
pinguins.columns
# Out:
# Index(['especie', 'ilha', 'comprimento_bico', 'largura_bico',
#        'comprimento_asa', 'peso', 'sexo'],
#       dtype='object')

# %%
pinguins.columns = ["especie", 'ilha', 'comprimento_bico', 'largura_bico', 'comprimento_asa', 'peso', 'sexo']

# %%
pinguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   especie           344 non-null    object
#  1   ilha              344 non-null    object
#  2   comprimento_bico  342 non-null    float64
#  3   largura_bico      342 non-null    float64
#  4   comprimento_asa   342 non-null    float64
#  5   peso              342 non-null    float64
#  6   sexo              333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
sns.histplot(pinguins['comprimento_bico'], bins = 20, kde = False)
# Out:
# <AxesSubplot:xlabel='comprimento_bico', ylabel='Count'>

# %%
sns.histplot(pinguins['comprimento_bico'], bins = 20, kde = True).set(title='Histplot')
# Out:
# [Text(0.5, 1.0, 'Histplot')]

# %%
sns.displot(pinguins['comprimento_bico'], bins = 20, kde = True, color = 'PURPLE').set(title='Displot')

# %%
sns.jointplot(data = pinguins, x = 'comprimento_bico', y = 'largura_bico')

# %%
sns.jointplot(data = pinguins, x = 'comprimento_bico', y = 'largura_bico', hue = 'especie', kind = 'kde')

# %%
sns.jointplot(data = pinguins, x = 'comprimento_bico', y = 'largura_bico', hue = 'sexo')

# %%
sns.jointplot(data = pinguins, x = 'comprimento_bico', y = 'largura_bico', kind = 'reg', marker = '+')

# %%
sns.jointplot(data = pinguins, x = 'comprimento_bico', y = 'largura_bico', kind = 'reg', marker = 'v')

# %%
sns.jointplot(data = pinguins, x = 'comprimento_bico', y = 'largura_bico',kind = 'reg', marker = '+', color = "red")

# %%
sns.jointplot(data = pinguins, x = 'comprimento_bico', y = 'largura_bico',kind = 'hist',bins = 30 , hue = 'especie')

# %%
sns.jointplot(data = pinguins, x = 'comprimento_bico', y = 'largura_bico',kind = 'hex')

# %%
sns.lmplot(data = pinguins, x = 'peso', y = 'comprimento_bico')

# %%
sns.lmplot(data = pinguins, x = 'peso', y = 'comprimento_bico', hue = 'especie', markers = ['+', 'v', '>'])

# %%
sns.lmplot(data = pinguins, x = 'peso', y = 'comprimento_bico', hue = 'sexo', markers = ['+', '^'])

# %%
sns.lmplot(data = pinguins, x = 'peso', y = 'comprimento_bico', hue = 'sexo', markers = ['+','<'])

# %%
sns.pairplot(pinguins)

# %%
pinguins.head()
# Out:
#   especie       ilha  comprimento_bico  largura_bico  comprimento_asa    peso  \
# 0  Adelie  Torgersen              39.1          18.7            181.0  3750.0
# 1  Adelie  Torgersen              39.5          17.4            186.0  3800.0
# 2  Adelie  Torgersen              40.3          18.0            195.0  3250.0
# 3  Adelie  Torgersen               NaN           NaN              NaN     NaN
# 4  Adelie  Torgersen              36.7          19.3            193.0  3450.0
#
#      sexo
# 0    Male
# 1  Female
# 2  Female
# 3     NaN
# 4  Female

# %%
pinguins.tail()
# Out:
#     especie    ilha  comprimento_bico  largura_bico  comprimento_asa    peso  \
# 339  Gentoo  Biscoe               NaN           NaN              NaN     NaN
# 340  Gentoo  Biscoe              46.8          14.3            215.0  4850.0
# 341  Gentoo  Biscoe              50.4          15.7            222.0  5750.0
# 342  Gentoo  Biscoe              45.2          14.8            212.0  5200.0
# 343  Gentoo  Biscoe              49.9          16.1            213.0  5400.0
#
#        sexo
# 339     NaN
# 340  Female
# 341    Male
# 342  Female
# 343    Male

# %% [markdown]
# Barplot

# %%
sns.barplot(data = pinguins, x = 'especie', y = 'comprimento_bico')
# Out:
# <AxesSubplot:xlabel='especie', ylabel='comprimento_bico'>

# %%
sns.barplot(data = pinguins, x = 'especie', y = 'comprimento_bico').set(title = 'barplot')
# Out:
# [Text(0.5, 1.0, 'barplot')]

# %%
pinguins['comprimento_bico'].unique()
# Out:
# array([39.1, 39.5, 40.3,  nan, 36.7, 39.3, 38.9, 39.2, 34.1, 42. , 37.8,
#        41.1, 38.6, 34.6, 36.6, 38.7, 42.5, 34.4, 46. , 37.7, 35.9, 38.2,
#        38.8, 35.3, 40.6, 40.5, 37.9, 37.2, 40.9, 36.4, 42.2, 37.6, 39.8,
#        36.5, 40.8, 36. , 44.1, 37. , 39.6, 37.5, 42.3, 40.1, 35. , 34.5,
#        41.4, 39. , 35.7, 41.3, 41.6, 35.5, 41.8, 33.5, 39.7, 45.8, 42.8,
#        36.2, 42.1, 42.9, 35.1, 37.3, 36.3, 36.9, 38.3, 34. , 38.1, 33.1,
#        43.2, 41. , 45.6, 42.7, 40.2, 35.2, 41.5, 38.5, 43.1, 36.8, 35.6,
#        32.1, 40.7, 46.5, 50. , 51.3, 45.4, 52.7, 45.2, 46.1, 46.6, 51.7,
#        47. , 52. , 45.9, 50.5, 50.3, 58. , 46.4, 49.2, 42.4, 48.5, 50.6,
#        46.7, 49.5, 52.8, 54.2, 51. , 49.7, 47.5, 47.6, 46.9, 53.5, 49. ,
#        46.2, 50.9, 45.5, 50.8, 50.1, 51.5, 49.8, 48.1, 51.4, 45.7, 50.7,
#        52.2, 49.3, 50.2, 51.9, 46.8, 55.8, 43.5, 49.6, 48.7, 43.3, 48.4,
#        45.1, 46.3, 44.5, 47.8, 48.2, 47.3, 59.6, 49.1, 42.6, 44.4, 44. ,
# ...

# %%
pinguins[pinguins['especie'] == 'Adelie']['peso'].mean()
# Out:
# 3700.662251655629

# %%
pinguins[pinguins['especie'] == 'Adelie']['comprimento_bico'].unique()
# Out:
# array([39.1, 39.5, 40.3,  nan, 36.7, 39.3, 38.9, 39.2, 34.1, 42. , 37.8,
#        41.1, 38.6, 34.6, 36.6, 38.7, 42.5, 34.4, 46. , 37.7, 35.9, 38.2,
#        38.8, 35.3, 40.6, 40.5, 37.9, 37.2, 40.9, 36.4, 42.2, 37.6, 39.8,
#        36.5, 40.8, 36. , 44.1, 37. , 39.6, 37.5, 42.3, 40.1, 35. , 34.5,
#        41.4, 39. , 35.7, 41.3, 41.6, 35.5, 41.8, 33.5, 39.7, 45.8, 42.8,
#        36.2, 42.1, 42.9, 35.1, 37.3, 36.3, 36.9, 38.3, 34. , 38.1, 33.1,
#        43.2, 41. , 45.6, 42.7, 40.2, 35.2, 41.5, 38.5, 43.1, 36.8, 35.6,
#        32.1, 40.7])

# %%
pinguins[pinguins['especie'] == 'Chinstrap']['comprimento_bico'].mean()
# Out:
# 48.83382352941177

# %%
pinguins[pinguins['especie'] == 'Gentoo']['comprimento_bico'].mean()
# Out:
# 47.50487804878048

# %%
pinguins[pinguins['especie'] == 'Gentoo']['largura_bico'].mean()
# Out:
# 14.982113821138212

# %%
sns.pairplot(pinguins)

# %%
sns.pairplot( pinguins , hue = 'especie')

# %% [markdown]
# CountPlot

# %%
sns.countplot( data = pinguins, x = 'especie').set(title = 'CountPlot')
# Out:
# [Text(0.5, 1.0, 'CountPlot')]

# %%
pinguins['especie'].value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: especie, dtype: int64

# %% [markdown]
# BoxPlot

# %%
sns.boxplot(data = pinguins, x = 'especie', y = 'peso')
# Out:
# <AxesSubplot:xlabel='especie', ylabel='peso'>

# %%
sns.boxplot(data = pinguins, x = 'especie', y = 'peso', hue = 'sexo')
# Out:
# <AxesSubplot:xlabel='especie', ylabel='peso'>

# %% [markdown]
# VIOLLINPLOT

# %%
sns.violinplot( data = pinguins, x = 'especie', y = 'peso')
# Out:
# <AxesSubplot:xlabel='especie', ylabel='peso'>

# %%
sns.violinplot( data = pinguins, x= 'especie', y = 'peso', hue = 'sexo')
# Out:
# <AxesSubplot:xlabel='especie', ylabel='peso'>

# %%
sns.violinplot(data = pinguins, x = 'especie', y = 'peso', hue = 'sexo', split = True)
# Out:
# <AxesSubplot:xlabel='especie', ylabel='peso'>
